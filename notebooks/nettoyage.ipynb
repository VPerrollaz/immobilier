# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - Phase finale de nettoyage (gestion des NaN et remplacement des catégories par des nombres).
# - Entraîner des modèles
# - Idéntifier les bonnes affaires

# %% [markdown]
# # Récupération des données

# %%
data = pd.read_csv("data.tsv", sep="\t")

# %%
data.head()
# Out:
#                          Id        Genre  Neuf  Surface  Pieces    Quartier  \
# 0  annonce-138905473-376235  Appartement     0    90.00     3.0  cathédrale
# 1  annonce-140620177-376235  Appartement     0   146.27     5.0         sud
# 2  annonce-140620179-376235  Appartement     0   110.00     5.0   prébendes
# 3  annonce-133494153-376235       Maison     0   132.00     6.0   prébendes
# 4  annonce-137425993-376235       Maison     0   185.00     7.0  strasbourg
#
#        Prix
# 0  374400.0
# 1  499200.0
# 2  499200.0
# 3  508000.0
# 4  676000.0

# %%
print(data.dtypes)
# Out:
# Id           object
# Genre        object
# Neuf          int64
# Surface     float64
# Pieces      float64
# Quartier     object
# Prix        float64
# dtype: object

# %% [markdown]
# # Gestion des nan dans les colonnes numériques

# %%
X1 = data[["Neuf", "Surface", "Pieces"]].values

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy = 'median')

# %%
imputer = imputer.fit(X1)

# %%
np.all(X1 == imputer.transform(X1))
# Out:
# False

# %%
X1 = imputer.transform(X1)

# %% [markdown]
# # Gestion des colonnes catégoriques

# %%
from sklearn.pipeline import make_pipeline

# %%
genre, quartier = data.Genre.values, data.Quartier.astype("category").values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder_X = LabelEncoder()

# %%
genre = labelencoder_X.fit_transform(genre)

# %%
np.unique(genre)
# Out:
# array([0, 1])

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
quartier.dtype
# Out:
# CategoricalDtype(categories=['2 lions', 'beaujardin', 'béranger', 'cathédrale', 'centre',
#                   'cher', 'cluzel', 'conservatoire', 'eloi', 'febvotte',
#                   'fontaines', 'gare', 'halles', 'heurteloup', 'mairie',
#                   'montjoyeux', 'nord', 'paul bert', 'portes', 'prébendes',
#                   'radegonde', 'rotonde', 'strasbourg', 'sud', 'tranchée',
#                   'velpeau'],
#                  ordered=False)

# %%
set(quartier)
# Out:
# {'2 lions',
#  'beaujardin',
#  'béranger',
#  'cathédrale',
#  'centre',
#  'cher',
#  'cluzel',
#  'conservatoire',
#  'eloi',
#  'febvotte',
#  'fontaines',
#  'gare',
#  'halles',
#  'heurteloup',
#  'mairie',
#  'montjoyeux',
#  nan,
#  'nord',
#  'paul bert',
#  'portes',
#  'prébendes',
#  'radegonde',
#  'rotonde',
#  'strasbourg',
#  'sud',
#  'tranchée',
#  'velpeau'}

# %%
x = quartier[98]

# %%
l, o = LabelEncoder(), OneHotEncoder()

# %%
q.shape
# Out:
# (1647, 667)

# %% [markdown]
# # Récupération target

# %%
y = data.Prix.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-19f7ef69ea28> in <module>()
#       1 from sklearn.linear_model import LinearRegression
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     507         else:
#     508             self.coef_, self._residues, self.rank_, self.singular_ = \
# --> 509                 linalg.lstsq(X, y)
#     510             self.coef_ = self.coef_.T
#     511
#
# ~\Anaconda3\lib\site-packages\scipy\linalg\basic.py in lstsq(a, b, cond, overwrite_a, overwrite_b, check_finite, lapack_driver)
#    1153     """
#    1154     a1 = _asarray_validated(a, check_finite=check_finite)
# -> 1155     b1 = _asarray_validated(b, check_finite=check_finite)
#    1156     if len(a1.shape) != 2:
# ...

# %%
data.head()
# Out:
#                           ID          Genre  Neuf  Surface Pieces  \
# 0  annonce-138905473-376235    Appartement      0     90.0     3
# 1  annonce-140620177-376235    Appartement      0   146.27     5
# 2  annonce-140620179-376235    Appartement      0    110.0     5
# 3  annonce-133494153-376235         Maison      0    132.0     6
# 4  annonce-137425993-376235         Maison      0    185.0     7
#
#        Quartier     Prix
# 0   cathédrale    374400
# 1          sud    499200
# 2    prébendes    499200
# 3    prébendes    508000
# 4   strasbourg    676000

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     821         try:
# --> 822             x = float(x)
#     823         except Exception:
#
# ...

# %%
# Out:
# array([[  1.  ,   0.  ,   0.  ,  90.  ,   3.  ],
#        [  1.  ,   0.  ,   0.  , 146.27,   5.  ],
#        [  1.  ,   0.  ,   0.  , 110.  ,   5.  ],
#        ...,
#        [  1.  ,   0.  ,   0.  ,  76.  ,   3.  ],
#        [  0.  ,   1.  ,   1.  ,  84.4 ,   4.  ],
#        [  0.  ,   1.  ,   1.  ,  84.4 ,   4.  ]])
